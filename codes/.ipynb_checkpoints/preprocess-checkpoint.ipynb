# %%
import pandas as pd
df = pd.read_csv('../datasets/gabaeoh_data_from_hiDoc.csv')
df[:3]
# Out:
#                         _id   question_title  \
# 0  64fece172822f039eb37dab3          강직성 척추염
# 1  64fece172822f039eb37dab4  척추골절 수술 문의드립니다.
# 2  64fece172822f039eb37dab5  척추골절 수술 문의드립니다.
#
#                                     question_content question_date  \
# 0  선생님.\n\n강직성 척추염 환자의 90~95%에서 관련 유전자가 검출된다고 하셨는...    2016.03.18
# 1  60대 여성입니다.\n얼마전 허리상해로 mri 를 찍었는데\n병원 주치의 설명으로 ...    2023.05.23
# 2  60대 여성입니다.\n얼마전 허리상해로 mri 를 찍었는데\n병원 주치의 설명으로 ...    2023.05.23
#
#                                       question_tag          answer_title  \
# 0  SMART TAG : 근골격계, 뼈, 정신/신경계, 내과, 류마티스내과, 강직성척추염          Re : 강직성 척추염
# 1         SMART TAG : 근골격계, 뼈, 척추, 정형외과, 재활의학과, 골절  Re : 척추골절 수술 문의드립니다.
# 2         SMART TAG : 근골격계, 뼈, 척추, 정형외과, 재활의학과, 골절  Re : 척추골절 수술 문의드립니다.
#
#   answer_name answer_belong                                     answer_content
# 0   이정찬 [전문의]     서울조인트내과의원  안녕하세요, 하이닥 류마티스내과 상담의 이정찬 입니다.\n\n강직성 척추염의 증상이...
# 1   이이호 [전문의]        진주고려병원      질문자의 감사 인사 | 2023.05.23\n많은 도움이 되었습니다. 고맙습니다.
# 2   이이호 [전문의]        진주고려병원      질문자의 감사 인사 | 2023.05.23\n많은 도움이 되었습니다. 고맙습니다.

# %%
df_question = df[['question_content', 'question_date','question_tag']]

# %%
df_question.to_excel('../datasets/select_colums.xlsx')

# %% [markdown]
# ## 전처리

# %% [markdown]
# ### 결측치 처리

# %%
df_question.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10570 entries, 0 to 10569
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   question_content  10283 non-null  object
#  1   question_date     10570 non-null  object
#  2   question_tag      10561 non-null  object
# dtypes: object(3)
# memory usage: 247.9+ KB

# %%
df_question = df_question.dropna()
df_question.isnull().sum()
# Out:
# question_content    0
# question_date       0
# question_tag        0
# dtype: int64

# %% [markdown]
# ### 자연어 처리
# - 불용어 처리
# - 한글자 처리

# %%
df_stop_words = pd.read_excel('../datasets/stop_words.xlsx')
df_stop_words[:5]
# Out:
#   불용어 리스트(stop word)
# 0                  가
# 1               가까스로
# 2                 가령
# 3                  각
# 4                 각각

# %%
#!pip install python-mecab-ko pyLDAvis

# %%
from mecab import MeCab
mecab = MeCab()

# %%
stopwords = df_stop_words['불용어 리스트(stop word)'].values
def tokenizer(raw, stopword=stopwords):
    result_list = list()
    for word in mecab.nouns(raw) :
        if len(word) > 1 and word not in stopword :
            result_list.append(word)
    return ' '.join(result_list) # return str

# %%
mecab.nouns('아무곳에서나 보고 억지로라도 운동할수 있어서 너무 좋습니다. 감사히 잘 쓸께요.')
# Out:
# ['곳', '운동', '수']

# %%
# 형태 분석기 적용된 함수 실행
tokenizer('아무곳에서나 보고 억지로라도 운동할수 있어서 너무 좋습니다. 감사히 잘 쓸께요.')
# Out:
# '운동'

# %%
df_question['tokenized_content']= df_question['question_content'].apply(tokenizer)
df_question[:2]
# Out:
#                                     question_content question_date  \
# 0  선생님.\n\n강직성 척추염 환자의 90~95%에서 관련 유전자가 검출된다고 하셨는...    2016.03.18
# 1  60대 여성입니다.\n얼마전 허리상해로 mri 를 찍었는데\n병원 주치의 설명으로 ...    2023.05.23
#
#                                       question_tag  \
# 0  SMART TAG : 근골격계, 뼈, 정신/신경계, 내과, 류마티스내과, 강직성척추염
# 1         SMART TAG : 근골격계, 뼈, 척추, 정형외과, 재활의학과, 골절
#
#                                    tokenized_content
# 0  선생 강직 척추염 환자 관련 유전자 검출 유전자 검출 사람 정상 확률 증상 경우 척...
# 1  여성 허리 병원 주치 설명 군데 골절 흉추 군데 요추 군데 압박 골절 통증 척추 성...

# %% [markdown]
# ## 부정과 긍정 댓글 분리

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
sentences = list(df_question['tokenized_content'])

# %%
text = ' '.join(sentences)
text
# Out:
# '선생 강직 척추염 환자 관련 유전자 검출 유전자 검출 사람 정상 확률 증상 경우 척추염 의심 증상 정밀 검사 의견 부탁 여성 허리 병원 주치 설명 군데 골절 흉추 군데 요추 군데 압박 골절 통증 척추 성형술 척추 성형술 상해 허리 나사 수술 허리 위험 초반 나이 꼬부랑 할머니 가족 병원 진료 진료 서류 요청 보험 제출 소견 서에 방출 골절 산재 신청 소견 압박 골절 상반 소견 작성 골절 차이 의아 주치 허리 수술 나이 척추 성형술 이후 마음 허리 수술 고견 부탁 여성 허리 병원 주치 설명 군데 골절 흉추 군데 요추 군데 압박 골절 통증 척추 성형술 척추 성형술 상해 허리 나사 수술 허리 위험 초반 나이 꼬부랑 할머니 가족 병원 진료 진료 서류 요청 보험 제출 소견 서에 방출 골절 산재 신청 소견 압박 골절 상반 소견 작성 골절 차이 의아 주치 허리 수술 나이 척추 성형술 이후 마음 허리 수술 고견 부탁 제목 척추 디스크 장증 사진 척추 오더 느낌 제목 척추 디스크 장증 사진 척추 오더 느낌 척추 전방 위증 진단 협착증 상태 허리 통증 왼쪽 엉치 무릎 윗부분 통증 통증 운동 마사이 신발 도움 도움 말씀 부탁 척추 마디 정도 잠자리 치료 복시 허리 디스크 재발 척추 상황 비용 부담 병원 요청 가능 작년 가을 지난달 척추 분리 진단 상태 척추 전방 위증 라인 다리 통증 반복 가지 질문 척추 분리 치료 가능 일상 생활 불편 운동 불편 의사 선생 운동 운동 피부 문제 때문 수영 가능 운동 병원 선생 의견 운동 그건 무리 때문 운동 물리치료 효과 물리치료 리리카 캡슐 처방 해결 문제 통증 작년 가을 지난달 척추 분리 진단 상태 척추 전방 위증 라인 다리 통증 반복 가지 질문 척추 분리 치료 가능 일상 생활 불편 운동 불편 의사 선생 운동 운동 피부 문제 때문 수영 가능 운동 병원 선생 의견 운동 그건 무리 때문 운동 물리치료 효과 물리치료 리리카 캡슐 처방 해
 장요 스트레칭 기립 스트레칭 불편 느낌 진단 하루 이틀 반복 전문직 시험 준비 헬스 조깅 시험 긴장 인지 허리 정도 침대 병원 척추 분리 진단 복용 정도 호전 산책 정도 시도 느낌 허리 고통 물리 치료 호전 산책 러닝 계단 걸까요 전문직 시험 준비 내년 공부 공부 방법 누가 척추 부분 정도 불편 느낌 장요 스트레칭 기립 스트레칭 불편 느낌 여성 허 ...

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

wordCloud = WordCloud(font_path=font_path, background_color='white') #인스턴스화 
wordCloud.generate_from_text(text)

# %%
wordCloud.words_
# Out:
# {'허리 통증': 1.0,
#  '강직 척추염': 0.7566735112936345,
#  '척추 분리': 0.6083162217659137,
#  '척추관 협착증': 0.4753593429158111,
#  '압박 골절': 0.4471252566735113,
#  '허리 디스크': 0.3896303901437372,
#  '의사 선생': 0.364476386036961,
#  '전방 위증': 0.3413757700205339,
#  '척추 전방': 0.3069815195071869,
#  '물리 치료': 0.3008213552361396,
#  '통증 통증': 0.263347022587269,
#  '왼쪽 다리': 0.26283367556468173,
#  '대학 병원': 0.25205338809034905,
#  '일상 생활': 0.25051334702258726,
#  '통증 허리': 0.24794661190965092,
#  '척추 신경': 0.24178644763860369,
#  '수술 수술': 0.24075975359342916,
#  '허리 허리': 0.2402464065708419,
#  '척추 협착증': 0.22946611909650924,
#  '병원 척추': 0.22433264887063656,
#  '수술 허리': 0.22279260780287474,
#  '검사 결과': 0.21509240246406572,
#  '전문 병원': 0.19969199178644764,
#  '도수 치료': 0.19917864476386038,
#  '약물 치료': 0.19558521560574949,
#  '답변 부탁': 0.19250513347022588,
#  '척추 골반': 0.1919917864476386,
#  '협착증 수술': 0.1837782340862423,
#  '분리 증이': 0.17813141683778233,
#  '운동 운동': 0.1688911704312115,
#  '통증 발생': 0.1673511293634497,
#  '척추 마취': 0.1658110882956879,
#  '답변 감사': 0.16427104722792607,
#  '치료 방법': 0.1591375770020534,
#  '보존 치료': 0.15811088295687886,
#  '오른쪽 다리': 0.1555441478439425,
#  '척추염 환자': 0.15092402464065707,
#  '상담 내용': 0.14527720739219713,
#  '운동 허리': 0.14219712525667352,
#  '증상 허리': 0.13655030800821355,
#  '통증 학과': 0.13655030800821355,
#  '신경 주사': 0.13449691991786447,
#  '정도 통증': 0.13347022587268995,
#  '통증 증상': 0.1309034907597536,
#  '라운드 숄더': 0.1309034907597536,
#  '척추염 검사': 0.12885010266940453,
#  '골반 다리': 0.12782340862422997,
#  '상태 척추': 0.12525667351129363,
#  '소론 도정': 0.12320328542094455,
#  '마티스 내과': 0.12217659137577003,
#  '다리 증상': 0.11909650924024641,
#  '마약 진통제': 0.11858316221765913,
#  '척추 문제': 0.11704312114989733,
#  '무릎 통증': 0.11652977412731007,
#  '통증 의자': 0.11652977412731007,
#  '디스크 척추': 0.11601642710472279,
#  '검사 엑스레이': 0.11242299794661191,
#  '추간판 탈출증': 0.11190965092402463,
#  '엑스레이 검사': 0.11139630390143737,
#  '종합 병원': 0.10985626283367557,
#  '정형 외과': 0.10934291581108829,
#  '개월 정도': 0.10831622176591375,
#  '아침 통증': 0.10780287474332649,
#  '하루 종일': 0.10420944558521561,
#  '통증 부위': 0.1026694045174538,
#  '근력 운동': 0.1026694045174538,
#  '운동 신체': 0.1026694045174538,
#  '다리 통증': 0.10215605749486653,
#  '감사 안녕': 0.10215605749486653,
#  '안녕 개월': 0.10215605749486653,
#  '수술 병원': 0.10164271047227925,
#  '척추염 진단': 0.10164271047227925,
#  '골절 척추': 0.10112936344969199,
#  '증상 수술': 0.10061601642710473,
#  '통증 생각': 0.09856262833675565,
#  '주사 치료': 0.09856262833675565,
#  '하루 정도': 0.09804928131416837,
#  '협착증 진단': 0.09753593429158111,
#  '척추 골절': 0.09753593429158111,
#  '위증 진단': 0.09702258726899383,
#  '신경 성형술': 0.09650924024640657,
#  '건강 검진': 0.0959958932238193,
#  '엑스레이 척추': 0.09548254620123203,
#  '통증 척추': 0.09496919917864477,
#  '자율 신경': 0.0944558521560575,
#  '척추염 증상': 0.09342915811088295,
#  '허리 척추': 0.08983572895277207,
#  '통증 척추염': 0.08932238193018481,
#  '척추 전문': 0.08880903490759753,
#  '마디 통증': 0.08880903490759753,
#  '강화 운동': 0.08829568788501027,
#  '골반 통증': 0.087782340862423,
#  '척추 교정': 0.08726899383983573,
#  '교정 운동': 0.08675564681724846,
#  '통증 시작': 0.08675564681724846,
#  '척추염 아침': 0.08675564681724846,
#  '통증 왼쪽': 0.08624229979466119,
#  '다리 정도': 0.08624229979466119,
#  '염증 수치': 0.08572895277207392,
#  '증상 호전': 0.08521560574948665,
#  '엉덩이 통증': 0.08470225872689939,
#  '허리 보호': 0.08470225872689939,
#  '허리 상태': 0.08470225872689939,
#  '척추염 의심': 0.08418891170431211,
#  '분리 척추': 0.08418891170431211,
#  '척추 성형술': 0.08367556468172485,
#  '척추뼈 인대': 0.08367556468172485,
#  '병원 진료': 0.08316221765913757,
#  '상태 운동': 0.08316221765913757,
#  '운동 골반': 0.08316221765913757,
#  '소염 진통제': 0.08264887063655031,
#  '치료 치료': 0.08264887063655031,
#  '부위 통증': 0.08264887063655031,
#  '내시경 수술': 0.08213552361396304,
#  '병원 신경외과': 0.08213552361396304,
#  '치오 프린': 0.08213552361396304,
#  '근전 검사': 0.08162217659137577,
#  '척추 디스크': 0.0811088295687885,
#  '일자 허리': 0.0811088295687885,
#  '신경 단술': 0.0811088295687885,
#  '소견 증상': 0.08008213552361396,
#  '수술 통증': 0.08008213552361396,
#  '동네 병원': 0.0795687885010267,
#  '수술 부위': 0.07905544147843943,
#  '골절 수술': 0.07905544147843943,
#  '마취 척추': 0.07854209445585215,
#  '문제 수술': 0.07854209445585215,
#  '근육 통증': 0.07854209445585215,
#  '허리 근육': 0.07751540041067762,
#  '문제 척추': 0.07700205338809035,
#  '정도 호전': 0.07700205338809035,
#  '아침 허리': 0.07700205338809035,
#  '검사 문제': 0.07700205338809035,
#  '생각 척추': 0.07648870636550308,
#  '증상 경우': 0.07597535934291581,
#  '병원 검사': 0.07597535934291581,
#  '치료 필요': 0.07597535934291581,
#  '통증 완화': 0.07546201232032854,
#  '소리 통증': 0.07443531827515401,
#  '조언 부탁': 0.07392197125256673,
#  '선생 말씀': 0.07392197125256673,
#  '척추 압박': 0.07392197125256673,
#  '경피 신경': 0.07392197125256673,
#  '안녕 척추': 0.0728952772073922,
#  '검사 검사': 0.0728952772073922,
#  '근육 증상': 0.0728952772073922,
#  '허리 골반': 0.07238193018480493,
#  '부탁 감사': 0.07238193018480493,
#  '진통 소염제': 0.07238193018480493,
#  '부위 척추': 0.07186858316221766,
#  '운동 상태': 0.07186858316221766,
#  '부분 통증': 0.07135523613963039,
#  '약물 복용': 0.07084188911704312,
#  '혈압 고지혈증': 0.07032854209445585,
#  '요추 디스크': 0.07032854209445585,
#  '양쪽 무릎': 0.06878850102669405,
#  '통증 엑스레이': 0.06878850102669405,
#  '허리 주사': 0.06878850102669405,
#  '원인 설명': 0.06827515400410678,
#  '증상 병명': 0.06827515400410678,
#  '치료 효과': 0.06776180698151951,
#  '얼굴 우측': 0.06776180698151951,
#  '엄지발가락 마디': 0.06776180698151951,
#  '의자 허리': 0.06724845995893224,
#  '자세 허리': 0.06724845995893224,
#  '왼쪽 오른쪽': 0.06724845995893224,
#  '신경 문제': 0.06724845995893224,
#  '주사 약물': 0.06724845995893224,
#  '시작 수술': 0.0662217659137577,
#  '병원 선생': 0.06570841889117043,
#  '통증 때문': 0.06570841889117043,
#  '고정 수술': 0.06570841889117043,
#  '척추 부분': 0.06519507186858316,
#  '골반 부분': 0.06519507186858316,
#  '검사 정상': 0.06519507186858316,
#  '골반 교정': 0.06519507186858316,
#  '통증 불편': 0.0646817248459959,
#  '척추염 가능': 0.06416837782340862,
#  '유전자 검사': 0.06365503080082136,
#  '척추뼈 소리': 0.06365503080082136,
#  '허리 엉덩이': 0.06365503080082136,
#  '진단 방법': 0.06314168377823409,
#  '의자 척추뼈': 0.06314168377823409,
#  '혈액 검사': 0.06314168377823409,
#  '신경 치료': 0.06262833675564682,
#  '질문 수술': 0.06262833675564682,
#  '척추 마디': 0.062114989733059546,
#  '수술 방법': 0.062114989733059546,
#  '결과 척추': 0.062114989733059546,
#  '진통제 복용': 0.062114989733059546,
#  '병원 방문': 0.062114989733059546,
#  '신경 손상': 0.062114989733059546,
#  '도움 부탁': 0.061601642710472276,
#  '자세 유지': 0.061601642710472276,
#  '오른쪽 허리': 0.061088295687885014,
#  '검사 유전자': 0.061088295687885014,
#  '호전 수술': 0.061088295687885014,
#  '상태 강직': 0.061088295687885014,
#  '사진 척추': 0.060574948665297744,
#  '디스크 증상': 0.060574948665297744}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off') 
plt.show()

# %%
#%matplotlib tk
# %matplotlib inline
