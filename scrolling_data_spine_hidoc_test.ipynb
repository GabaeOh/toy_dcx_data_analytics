# %%
from selenium import webdriver
import pandas as pd 
import pymongo as mg
import time

# %% [markdown]
# ## 웹사이트 : 하이닥
# - https://www.hidoc.co.kr/

# %%
browser = webdriver.Chrome(executable_path='../chromedriver.exe') 
browser.get('https://www.hidoc.co.kr/integratesearch/searchhealthqnalist?query=%EC%B2%99%EC%B6%94')

# %%
for next_page in range(1,10) :
    # next_page = 'span > a.ico_comm.btn_next'
    for page_number in range(2, 11) : # 첫 페이지는 tag가 달라짐
        element_path = '#hidocBody > div > div.coll_cont.coll_qna > div.paging_type1 > span > a:nth-child({})'.format(page_number)
        try : 
            pagination = browser.find_element_by_css_selector(element_path)
            pagination.click()
            time.sleep(2) # term을 주기
            print("성공 : {} ".format(page_number))
        except : 
            print("오류")
    next_page = browser.find_element_by_css_selector('span > a.ico_comm.btn_next').click()
# Out:
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[15], line 12
#      10     except :
#      11         print("오류")
# ---> 12 next_page = browser.find_element_by_css_selector('span > a.ico_comm.btn_next').click()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:598, in WebDriver.find_element_by_css_selector(self, css_selector)
#     582 def find_element_by_css_selector(self, css_selector):
#     583     """
#     584     Finds an element by css selector.
#     585
#    (...)
#     596         element = driver.find_element_by_css_selector('#foo')
#     597     """
# --> 598     return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"span > a.ico_comm.btn_next"}
#   (Session info: chrome=116.0.5845.180)

# %%
answers_bundle = browser.find_elements_by_css_selector('.box_type1.hidoc_answer')
len(answers_bundle)
# Out:
# 2

# %%
# 질문 리스트 가져오기 
questions_bundle = browser.find_elements_by_css_selector('.link_qna')
answer_list = []

# 게시물 질문 가져오기 
for question_bundle in questions_bundle:
    # 각 질문 클릭
    question_bundle.click()

    # 질문에 관한 정보 
    try:
        question_title = browser.find_element_by_css_selector('div.box_type1.view_question > div.inner > strong').text
    except : 
        question_title = str()
    try:
        question_content = browser.find_element_by_css_selector('div.desc > p').text
    except :
        question_content = str()
    try:
        question_date = browser.find_element_by_css_selector('div.inner > div.clear_g > div.user_info > span').text
    except :
        question_date = str()
    try : 
        question_tag = browser.find_element_by_css_selector('div.inner > div.txt_tag').text
    except :
        question_tag = str()

    # 답변의 총 갯수 파악
    answers_bundle = browser.find_elements_by_css_selector('.box_type1.hidoc_answer')

    for answer in answers_bundle: 
        try : 
            answer_title = answer.find_element_by_css_selector('.tit_answer').text
        except :
            answer_title = str()
        try : 
            answer_name = answer.find_element_by_css_selector('div.answer_head > div.doctor_clinic > a').text
        except: 
            answer_name = str()
        try : 
            answer_belong = answer.find_element_by_css_selector(' div.answer_head > div.doctor_clinic > span').text
        except:
            answer_belong=str()
        try : 
            answer_content = answer.find_element_by_css_selector('div.answer_body > div').text
        except:
            answer_content = str()

        answers_list = [question_title, question_content, question_date, question_tag, answer_title, answer_name, answer_belong, answer_content ]
        answer_list.append(answers_list)
    browser.back()

# %%
answer_list
# Out:
# [['',
#   '',
#   '',
#   '',
#   '',
#   '허성우 [전문의]',
#   '성모엄지척정형외과의원',
#   '안녕하세요. 하이닥 정형외과 상담의 허성우입니다.\n\n후종인대 골화증을 이야기 하는게 아닌가 싶은데요..\n\n증상에 따라 수술이 필요할 수 있습니다.\n\n쉽게 생각을 하시면 하수도관에 물이 잘 흐르는 경우엔 찌거기가 좀 차 있어도 문제가 그리 되지 않으나,\n\n양이 많이 물 흐름을 방해한다면 제거를 해야하는 것이죠.\n\n신경이 지나가는 통로가 좁아져 그 증상으로 힘들어 하시는 것 같으니\n\n약물이나, 주사 치료에 호전이 없다면 시술 혹은 수술을 고려하심이 좋을 듯 합니다.\n\n당연할 수 있습니다만, 주저하시면 자료를 첨부하시어 대학병원을 방문해보심도 대안이 될 수 있습니다.\n\n쾌유바라겠습니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '이이호 [전문의]',
#   '진주고려병원',
#   '안녕하세요. 하이닥 외과 상담의 이이호입니다.\n\n척추석회증은 척추의 뼈가 비정상적으로 석회화되는 질환으로, 종아리에 통증이나 뭉침과 같은 증상을 일으킬 수 있습니다. 척추의 석회화로 인해 신경이 압박을 받아 종아리 근육의 기능이 감소하거나 통증이 발생할 수 있습니다.\n\n수술 여부는 모친의 증상과 척추 석회증의 정도에 따라 결정되어야 합니다. 일반적으로 척추 석회증은 보존적인 치료를 시도한 후 증상의 심각성과 생활의 질에 영향을 미치는지 여부를 평가하여 수술이 필요한지 판단합니다. 모친께서는 이미 의사의 진단으로 수술이 필요하다고 말씀하셨으므로, 이 부분에 대해서는 의료 전문가의 조언을 따르시는 것이 가장 좋습니다.\n\n종아리를 풀어주기 위해서는 척추 석회증과 관련된 근육 강화 및 유연성 향상 운동, 체형교정, 물리 치료, 스트레칭 등을 고려할 수 있습니다. 그러나 종아리 증상의 원인이 척추 석회증이라면, 수술 및 수술 후의 치료 및 재활 프로그램을 통해 종아리 증상을 개선시킬 수 있습니다. 이는 의료 전문가와 상담하여 개별적인 상황에 맞는 조치를 결정하는 것이 좋습니다.\n\n모친이 혈압약과 고지혈증 약을 복용 중이라면, 이에 대한 관리와 조절은 계속해서 의료 전문가와 협의해야 합니다. 모친의 약물 복용 상태와 척추 석회증의 수술 및 치료 계획은 서로 연관되므로, 의사와 상담하여 약물 복용과 관련된 주의사항 및 수술 전후의 관리 방법을 정확히 이해하고 따르는 것이 중요합니다.\n\n위의 내용은 일반적인 정보일 뿐이며, 모친의 상황에 따라 달라질 수 있습니다\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '임경린 [전문의]',
#   '엘에스정형외과의원',
#   '질문자의 감사 인사 | 2020.05.18\n많은 도움이 되었습니다. 고맙습니다.'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '이주홍 [전문의]',
#   '참바로병원',
#   '안녕하세요? 하이닥 정형외과 상담의 이주홍 입니다.\n\n척추 전방 전위증인가요?\n기술하신 질문으로는 제대로 상태 파악이 안되지만 추측으로는 전방 전위증인것 같습니다.\n\n장애는 마비가 있고 객관적으로 증명할 수 있는 자료가 있어야 나옵니다.\n따라서 환자분은 장애 판정을 받기는 힘들어 보입니다.\n\n치료는 상태에 따라 보존적 치료부터 수술적 치료까지 있고 환자 상태에 따라 결정합니다.\n정확한 기술이나 의사의 소견을 질문에 넣어주셔야 만족할만한 답변 드릴수 있겠습니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '염경성 [전문의]',
#   '바로본병원',
#   '안녕하세요. 하이닥 정형외과 상담의 염경성 입니다.\n\n나이를 보니까 십대후반이나 20대 정도 되실 거 같은데요.\n사진상 척추가 많이 휘었다고 하는데 통증이 있으신지 궁금하네요.\n여자분은 환자분 나이면 이미 성장이 끝났다고 보는데요.\n사진상 각도가 중요합니다.\n40도 이상이면 수술적 치료도 필요하지만\n대개는 40도 까지는 가진 않습니다.\n\n보조기구는 사용해도 되지만 환자분 연령에서는 큰 도움이 안될 수도 있습니다. 대신에 전체적으로 봐서 머리부터 골반까지 균형은 잡혀있다면\n수영같은 전신 근육을 발달시키는 운동요법이 제일 좋습니다.\n\n우리의 몸은 척추가 한쪽으로 휘면 다시 반대쪽으로 휘어 전체적으로\n균형을 잡으려고 하기때문에 겉으로 봐서는 잘 모르는 수도 있습니다.\n\n척추 전문병원에 들러서 정확한 각도와 균형여부를 다시 검사하시고\n거기에 따른 처방을 따르는 것이 좋을 것으로 사료됩니다.\n\n좋은 답변이 되었길 바랍니다.\n감사합니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '이이호 [전문의]',
#   '진주고려병원',
#   '안녕하세요. 하이닥 외과 상담의 이이호입니다.\n\n위에서 언급하신 증상과 허리의 비대칭 및 척추노화와 관련하여 생각할 수 있는 몇 가지 가능성이 있습니다. 하지만 질환의 정확한 원인을 판단하려면 전문의의 진단과 검사가 필요합니다. 아래에 몇 가지 가능한 원인을 제시해보겠습니다.\n\n1. 척추 변형: 비대칭한 자세로 오랜 기간 동안 근무하거나 허리를 부담하는 활동을 많이 한 경우 척추의 변형이 생길 수 있습니다. 이로 인해 신경뿐만 아니라 혈액순환이나 근육에도 영향을 미칠 수 있습니다.\n\n2. 척추통증: 척추의 변형이나 부담으로 인해 척추 주변의 근육, 인대, 신경에 염증이 생길 수 있습니다. 이로 인해 통증이나 불편감이 발생할 수 있습니다.\n\n3. 척추 신경통: 척추 주변의 신경이 압박을 받거나 염증이 생길 경우 신경통이 발생할 수 있습니다.\n\n4. 척추 관절염: 척추 관절의 염증이나 변형으로 인해 통증과 불편감이 생길 수 있습니다.\n\n5. 척추 디스크 문제: 척추 디스크의 탄력이 감소하거나 디스크가 미세하게 튀어나와 신경을 자극할 경우 허리 불편감이나 통증이 나타날 수 있습니다.\n\n상기한 가능성 중에서 어떤 원인이 해당되는지 정확히 판단하려면 정확한 의료진 진단이 필요합니다. 따라서 허리의 불편함과 증상이 계속되는 경우 정확한 진단을 위해 정밀한 검사와 의사의 상담을 받는 것이 좋습니다. 이를 통해 적절한 치료와 관리 방법을 결정하실 수 있습니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '유재돈 [의사]',
#   'HiDoc',
#   '안녕하세요. 하이닥 정형외과 상담의 유재돈 입니다.\n\n척추분리증이 일반사람들 보다 문제를 일으킬 확률이 높은 것은\n사실입니다만 척추분리증을 가지고도 잘 살아가는 사람들도 있습니다.\n\n척추는 그 사이에 디스크가 있고 관절이 위의 척추와 아래척추로\n있으며 인대와 근육으로 연결되어 있습니다.\n\n가장 중요한 것은 디스크나 관절, 인대와 근육이 다 같이 힘을 합쳐서\n모양도 유지하고 몸무게도 받아내는 것이지요.\n척추분리증이 있어도 만약에 디스크가 건강하고 인대나 근육이 분리증을\n잡아줄 만큼 강하다고 한다면 크게 문제를 일으키지 않고도\n생활이 가능합니다.\n\n따라서 하셔야 할 일은 앞으로 척추에 무리를 주는 동작이나\n생활습관을 피하고 근육이나 인대를 강하게 하는 자신에게\n알맞은 운동을 선택하셔서 꾸준히 노력하신다면 어쩌면 방심하고\n있다가 척추병에 걸리는 사람보다 전화위복이 되실 수도 있습니다.\n\n평생요통을 겪을 것이면 이미 겪고 계실 것인데 그렇지 않으니\n미리 걱정하실 필요는 전혀 없습니다. 그리고 앞의 택시를 받으셨다는\n것으로 보아서는 충격으로 인해서 분리증이 생겼을 가능성은\n크지 않을 것 같습니다.\n\n도움이 되셨길 바라고 용기 내셔도 충분한 상황으로 보이니\n힘내시기 바랍니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '유재돈 [의사]',
#   'HiDoc',
#   '안녕하세요. 하이닥 정형외과  상담의 유재돈입니다.\n\n척추의 문제가 생긴 경우에는 여러가지 상태가 동시에 나빠진 경우가 많습니다. 즉 허리를 구성하는 디스크나 관절, 인대, 근육 등 여러가지 구조물이 서로간에 영향을 주게 되어 있습니다. 예를 들어 디스크를 오래가지고 계신 경우에 협착증으로 발전될 확률이 높으며 또한 근육이나\n인대의 문제는 항상 동반되는 경향이 있습니다.\n\n따라서 협착증 수술을 하여서 문제가 해결되셨다해도 허리자체가 강해진 것은 아니기 때문에 수술후의 처치도 매우 중요합니다.\n\n또한 척추협착증이 한 부분에서만 생긴 것이 아니라 여러부위에 생길 수도 있는 만큼 수술후에 심하게 움직인다는 것 자체를 주의하셔야 합니다.\n\n다리가 아프고 압박감이 오는 증상은 재발이 아니라도 얼마든지 올 수 있는 증세입니다. 근막동통증후군이나 후관절 증후군 같이 관절이나 근육의 문제등으로도 올 수 있으니 만큼 적절한 치료를 받으시면서 허리를 과사용하는 것은 금하시고평소에 허리를 보다 더 건강하게 할 수 있는 생활습관과 운동을 꾸준히 병행하셔야 합니다.\n\n무리하지 않으시는 경우에도, 증세가 계속되시거나 악화되실 경우에는 보다 정밀 검사를 해보셔야 할 것으로 보입니다.\n오실 수 있는 증상이니 너무 염려마시고 잘 치료해 주시기 바랍니다.\n\n도움이 되셨길 바라고 좋은 결과를 기원합니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '허성우 [전문의]',
#   '성모엄지척정형외과의원',
#   '안녕하세요. 하이닥 정형외과 상담의 허성우입니다.\n\n현재 나이에서는 척추 관절염을 생각할 만한 증상은 없어 보입니다.\n\n무릎 자체의 문제나 소위 "디스크"라 지칭하는 추간판 탈출증 증상은 구분해야 할 질환으로 가까운 정형외과를 방문하시어 진찰을 받아 보심이 더 정확한 진단을 얻을 수 있는 방법 같습니다.\n\n감사합니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '신민철 [전문의]',
#   'HiDoc',
#   '안녕하세요? 하이닥 정형외과 상담의 신민철 입니다.\n척추협착증이 심하면 100,200m만 걸어도 힘들어 쪼그리고 앉아 쉬어야 합니다.\n장시간 보행 후 증상이 있으시면 어머니께서는 심한 것은 아니라고 사료됩니다.\n협착증이 많은 경우 퇴행성으로 유발되는데, 원인이되는 구부정하거나 배나온 나쁜자세를 피하고 적당한 운동, 약물,물리치료를 꾸준히 받으면 퇴행성 진행을 최소화할 수 있습니다. 척추관 내 염증, 부종 등이 감소되어 치유되는 경우도 있습니다.\n심하지 않은 협착증은 수술 없이도 회복될 수 있으니 꾸준히 관리하시기 바랍니다.\n감사합니다.\n\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '김재호 [전문의]',
#   'HiDoc',
#   '안녕하세요. 하이닥 재활의학과 상담의 김재호입니다.\n\n원인이 중요한 건 아니지만\n선천적 분리증은 보통 남성에게 조금 더 많고\n후천적 분리증은 여성분들에게 많습니다.\n\n음 아직 젊으시니 선천적일 수도 있고\n중요한 건 30년 후에 퇴행성 척추증이 진행할 수 있으니\n척추 위생과 체중관리 신경쓰셔야 합니다.\n현재 체중은 표준체중으로 생각되지만\n여기서 더 증가하면 퇴행성이 더 빨리 더 심하게 올 수도 있으니까요.\n\n바른자세, 올바른 운동 중요한데\n보통 디스크 환자에게 신전운동이 좋지만, 전방전위증 환자에게는 삼가라고 합니다.\n범위는 아직 1기 정도니 과신전 말고 골반 전경만 조금 한다고 생각하면 됩니다.\n\n골반 중립 신경쓰면서 코어운동, 필라테스 하시고.\n수영 좋습니다. (접영은 금하고 자유형 권함)\n\n(선수가 아니라면 취미로 하는)\n신체접촉이 많거나 과한 운동, 체간을 심하게 비트는 운동, 한방향 운동도 금합니다.\n\n사실 1기면 크게 신경 안쓰고 살 수도 있지만\n목표는 40년 후에 3,4단계로 진행하여 수술이 필요하게 되는 경우를 예방하는 것이고요.\n따라서 지금은 젊고 증상이 없더라도 꾸준한 운동과 습관으로 평생 관리한다고 생각하면 됩니다.\n\n수면자세는 허리를 비트는 자세, 옆으로 누워 자는 습관 안 좋고요.\n그냥 바로 누워자는 습관이면 됩니다.\n굳이 비싸거나 기능성 매트리스? 방석 등 살 필요도 없고요.\n(만약 2기 정도가 되면 허리 사진을 보고 통증이 있는 경우 요추 밑에 수건 한장 정도 깔라고 하기도 합니다만\n같은 2기라도 신체상태에 따라 다르기 때문에 엑스레이사진을 봐야 합니다.)\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '최민규 [전문의]',
#   'HiDoc',
#   '질문자의 감사 인사 | 2022.09.06\n많은 도움이 되었습니다. 고맙습니다.'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '남경훈 [전문의]',
#   '등편한신경외과의원',
#   '안녕하세요 하이닥 신경외과 상담의 남경훈 입니다.\n둘은 좀 다른 개념입니다. 척추이분증은 spina bifida 라고 하구요, 척추분리증은 spondylolysis 라고 합니다. 척추이분증은 척추의 후궁이 완전히 닫히지 않은 상태를 말하며, 주로 하부 요추와 천추에 흔합니다.\n임상적으로 별다른 의미가 없는 선천적 기형입니다. 외상과도 별다른 연관이 없으며, 요통의 원인도 되지 않습니다.\n척추분리증은 척추후궁의 협부에 결손이 있는 경우입니다. 아직 원인은 완벽하게 이해되지 않지만, 반복적인 물리적인 스트레스나 외상에 의해 협부결손이 발생한다는 설이 유력한것으로 알려져 있습니다.\n그외에 선천적으로 골화점이 유합되지 못해 발생한다는 설, 출생시 외상에 의한다는 설, 무혈관성 괴사에 의해 발생한다는 설, 기립자세에 의한 반복적인 스트레스가 원인이라는 설, 유전적인 영향을 받는다는\n설, 반복적인 미세손상에 의한다는 설 등이 있습니다. 그러나 척추 분리증은 대부분 우연히 발견되며, 분리증이 있다고 모두 요통을 일으키지는 않지만, 외상등에 의해 요통이 발생할 빈도가 일반사람들에 비해\n다소 높을 수는 있습니다. 따라서 증상이 없다면 굳이 치료를 요하지 않습니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '이동환 [전문의]',
#   'the큰병원',
#   '안녕하세요. 하이닥 신경외과 상담의 이동환 입니다.\n\n문의 감사합니다.\n\n결론부터 말씀 드리면\n척추의 이상으로 하지 성장 및 관절에 영향을 줄 수 있습니다.\n\n척추 전만증이나 후만증, 측만증 같이 우리 몸의 기둥인 척추가\n균형이 바르지 않음으로 인해 고관절과 무릎관절, 심지어 발목 관절에도\n무리를 줄 수 있으면 중년 이후 퇴행성 관절염의 원인이 됩니다.\n따라서 성장기때 바른 자세를 유지 하는 것이 무척이나 중요합니다.\n\n늦었다고 생각하지 마시고, 지금이라도 바른 자세 유지 및\n허리 근력 강화 운동을 꾸준히 할 것을 권합니다.\n허리 근육이 강하면 이후 척추에 무리가 덜 오고\n또한 하지관절에도 무리가 가지 않기 때문입니다. \n\n꾸준한 운동으로 님의 건강한 척추, 건강한 관절을 응원합니다. \n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '조형준 [전문의]',
#   '조형준정형외과의원',
#   '안녕하세요. 하이닥 정형외과 상담의 조형준입니다.\n\n척추분리증이라는 것은 척추체과 극돌기로 이어지는 척추뼈가 분리되어 있는 병입니다.\n대부분은 선천적인 경우가 많고, 나이가 들어서 퇴행성 변화인경우가 대부분이고 매우 드문 경우 과거에 골절이 불유합이 되는 경우가 있지만 정말 매우 드문 경우입니다.\n\n대부분 선천적인 경우이고, 현재 나이가 젋으시기 때문에 척추분리증이라는 진단명으로 현재 증상을 파악할 것이 아니고. 이 질병과 별개로\n\n다른 질환, 디스크 탈출증 유무를 파악해야 할 것입니다.\n\n척추 분리증에 의한 통증이라면 대부분 자세를 바르게 하고 가벼운 스트레칭 하면서 근육을 잘 풀어주고 근력운동을 해주면 척추분리증이 해결되는 것은 아니나 근력으로 척추 불안정증이 해결되면서 증상이 완화됩니다.\n\n이것과 별개로 디스크가 터진 증상이라면 점차 방사통이 심해지거나 허리 및 다리 통증이 진행되면 디스크 치료가 필요할 수 있으므로 디스크 탈출 유무가 중요합니다.\n\nMRI 로 디스크 문제 별로 없다면, 무릎 수술로 근력이 약화 되어있으니 척추 분리증의 불안정증을 해결하기 위해 통증 조절을 약이나 물리치료 주사치료 등으로 해결을 하고 스트레칭과 근력운동을 해야 합니다.\n\n척추 분리증 만으로 수술을 하지는 않습니다. 그러나 척추분리증이 악화되면 척추전방전위증으로 진행되면 고정술 이라는 수술을 하기도 합니다.\n\n아직 젋으시기에 수술을 먼저 고민하기 보다는 증상악화되면 MRI 로 디스크 탈출 유무가 증상해결에 중요한 키가 될 것 같습니다.\n\n보통 통증이 생기고 2-4주간은 통증 조절을 위한 치료가 우선이고 증상이 악화되면 MRI 로 진단을 내립니다.\n\n그 동안은 최소한 2주간의 무리하지 않는 것이 좋습니다. 그렇다고 너무 누워계시기 보다는 걷기정도는 하는 것을 권합니다. 통증이 유발되지 않는 정도로요.\n\n빠른 쾌유를 빕니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '김용래 [전문의]',
#   'HiDoc',
#   '안녕하세요? 하이닥 정형외과 상담의 김용래 입니다.\n\n죄송합니다.\n\n질문이 잘못 배달되어 저에게 온 것 같습니다.\n\n저는 척추전문의가 아니라서 도움을 드릴 수 없네요.\n\n죄송하지만 다시한번 질문을 올려 주시면 감사하겠습니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '안녕하세요. 하이닥 신경외과 상담의 정동문입니다.\n\n골반, 척추가 틀어지는 것은 후천적 영향이 더 큽니다. 선천적으로 척추 변형이 있는 경우도 있지만 대개는 후천적으로\n자세가 안좋거나 하면서 틀어지는 경우가 더 많습니다. 이것이 유전이 되는것은 아닙니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '홍인표 [전문의]',
#   '닥터홍가정의학과의원',
#   '안녕하세요. 하이닥 가정의학과 상담의 홍인표입니다.\n골반 척추가 틀어진것도 어떤 종류냐에 따라서 유전이 되고 안되고 할수 있지만 일반적으로는 유전성향은 별로 없는 것으로 알고 있습니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '최은석 [전문의]',
#   '참조은병원',
#   '안녕하십니까 하이닥 신경외과 상담의 최은석 입니다.\n\n답변이 늦어 죄송합니다.\n 척추뼈 뒤쪽에 있는 인대나 작은근육 같은 연부조직이 일부 손상된 후\n그 흔적으로 이러한 증상이 지속 되는것 같습니다. 큰병은 아니지만\n너무 오래 지속되는듯 하니 치료를 하시는 것이 좋을것 같습니다.\n 일단 가까운 곳에 있는 신경외과, 정형외과나 통증 클리닉등을 방문하시어\n간단한 검사와 진찰후 치료하시면 불편함은 많이좋아질것으로 판단됩니다.\n 이후에는 적극적이고 지속적인 유산소 운동을 중심으로 하여\n운동을 꾸준히 해주시면 더욱 좋겠습니다.\n 이러한 증상은 좋지 못한 구부정한 자세등으로 인해 발생 되었을 가능성이\n크므로 항상 바른자세를 유지하도록 신경쓰시기 바랍니다.\n감사합니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '배규룡 [전문의]',
#   '세계로마취통증의학과의원',
#   '안녕하세요. 하이닥 마취통증의학과 상담의 배규룡 입니다.\n\n996명의 요통이 있는 사람들에서 척추분리증의 비율이 7.6%로\n일반인들에서 발견되는 4-6%의 척추분리증 환자 비율보다 아주 더\n많지는 않다 합니다.( Macnab; )\n따라서 요통이나 다리 당김이 있다면 척추분리증 때문에 아픈 것이라고 믿을 필요는 없다고 합니다.\n 즉, 척추분리증이 있는 사람에서 허리가 아프거나 다리 당김이 있다면\n일반인들에서 디스크 탈출증에 의해서 온 증상과 마찬가지로 치료하면\n된다는 것입니다.\n 즉, 허리 통증과 다리 통증이 척추분리증에 의해서 온 통증이라면\n다음과 같은 특징을 가지고 있습니다.\n이들은 디스크가 경막을 자극해서 오는 것이 아니므로 기침에 의해\n악화하지고 않고 누워서 다리를 펴고 들어 올리는 것이 지장을 받지 않는 것입니다.\n 따라서 기침에의해서 악화하지도 않고 다리를 펴고 들어 올려서 제한을 받지도 않고 고개를 숙여도 허리를 굽혀도 악화하지 않는 다면 척추분리증에 의한 통증으로 볼 수 있다는 말이 됩니다.\n척추분리증에 의해 생긴 허리통증은 인대강화로 치료해야 합니다.\n척추분리증으로 생긴 다리 당김 통증이 심하면 신경근차단주사로 치료하고 보조기인 콜셋 착용을 힘든 일을 할 때 해야 합니다.\n이런 방법으로 다리 당김을 없앨 수 없으면 수술해야 합니다.\n또 척추미끄럼증이 점점 심해지던가,  75%  이상 미끄러지면\n수술을 고려해 보아야 합니다.\n그러나 미끄럼이 심한 경우에도 비수술적인 방법의 치료로도 결과가\n좋았다 합니다.\n 심하지 않은 척추분리증으로 인한 척추미끄럼증에서의 수술 요법은\n비수술적 요법보다 더 결과가 좋지는 않았다 합니다.\n 만약 디스크가 생겨서 오는 통증이라면 기침시, 고개를 숙일 시, 허리를 굽힐 시, 통증이 더 심하고 누워서 다리 펴고 올릴 때 올라가지 않으면\n디스크 탈출증과 같이 치료하는 것입니다\n척추분리증 환자에서의 디스크 탈출증 치료는 척추분리증이 없는 정상\n사람의 디스크 탈출증 치료와 같은 방법으로 치료하면 됩니다\n즉, 경막외신경차단주사 요법과 견인을 포함한 물리치료로 치료하는 것입니다.\n그러나 척추분리증 환자에서 디스크가 발생한 사람은 자주 재발하는 경향이 있어\n디스크 치료후 인대강화를 해주면 재발이 방지된다 합니다.\n 정리하면 현재의 다리 통증과 허리 통증이 척추분리증에 의한 척추미끄럼증 때문에\n온 것인지 척추미끄럼증의 정도를 방사선 사진으로 찍어\n관찰하고 전의 사진과 대조해서 더 심해졋는지 보고 mri로 디스크 탈출증이 있는지 확인하고 현재의 통증이 디스크 탈출증의 특징인 기침에 의해 울리는 통증인지 다리를 펴고 들어 올리는 검사에서 다리가 올라가지 않는지를 보아 디스크 통증에 의한 것이면 경막외신경차단주사 치료와 견인및 물리치료를 받고\n기침에 의한 악화하지 않고 다리 펴고 올리기가 지장을 받지 않고\n사진으로 척추분리증에이한 앞미끄럼증이 더 심해졌고 mri에서\n탈출된 디스크가 전혀 없다면 신경차단주사로 치료해 보고 통증이 없어지면 버티고 일을 할 때는 콜셋을 입어 보호하고 해 보아야 하며\n이런 것으로도 통증을 없앨 수 없다면 수술을 고려해 보아야 할 것입니다.\n    * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '안녕하세요. 하이닥 신경외과 상담의 정동문입니다.\n\n골반, 척추가 틀어지는 것은 후천적 영향이 더 큽니다. 선천적으로 척추 변형이 있는 경우도 있지만 대개는 후천적으로\n자세가 안좋거나 하면서 틀어지는 경우가 더 많습니다. 이것이 유전이 되는것은 아닙니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '홍인표 [전문의]',
#   '닥터홍가정의학과의원',
#   '안녕하세요. 하이닥 가정의학과 상담의 홍인표입니다.\n골반 척추가 틀어진것도 어떤 종류냐에 따라서 유전이 되고 안되고 할수 있지만 일반적으로는 유전성향은 별로 없는 것으로 알고 있습니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가'],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '이정찬 [전문의]',
#   '서울조인트내과의원',
#   '안녕하세요, 하이닥 류마티스내과 상담의 이정찬 입니다.\n\n강직성 척추염의 증상이 없고 여러 검사에서 정상인데 유전자 검사만 양성으로 나온 경우에는\n대부분이 정상으로 지내며 증상이 발현될 가능성이 아주 낮습니다.\n\n지금의 증상은 전형적인 강직성 척추염의 증상이 아닌것으로 사료 됩니다.\n천장 관절 MRI등의 정밀 검사는 진찰을 했던 담당 선생님과 상의후에 결정 하셔야 됩니다.\n\n감사합니다.\n  * 본 답변은 참고용으로 의학적 판단이나 진료행위로 해석될 수 없습니다.\n\n추천 이 전문가에게 묻기2 관심전문가로 추가']]

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')
database = client['study_data_analytics']
collection = database['data_spine_hidoc']

comm_list = []
for page_number in range(1, 10) : # 1에서 10까지 페이지 순회

    for pagenation in range(2,11):
        page_path = '#hidocBody > div > div.coll_cont.coll_qna > div.paging_type1 > span > a:nth-child({})'.format(pagenation)
        try : 
            time.sleep(1) # term을 주기
            print("성공 : {} ".format(pagenation))
            
            # 질문 리스트 가져오기 
            questions_bundle = browser.find_elements_by_css_selector('.link_qna')

            # 게시물 질문 가져오기 
            for question_bundle in questions_bundle:
                # 각 질문 클릭
                question_bundle.click()

                # 질문에 관한 정보 
                try:
                    question_title = browser.find_element_by_css_selector('div.box_type1.view_question > div.inner > strong').text
                except : 
                    question_title = str()
                try:
                    question_content = browser.find_element_by_css_selector('div.desc > p').text
                except :
                    question_content = str()
                try:
                    question_date = browser.find_element_by_css_selector('div.inner > div.clear_g > div.user_info > span').text
                except :
                    question_date = str()
                try : 
                    question_tag = browser.find_element_by_css_selector('div.inner > div.txt_tag').text
                except :
                    question_tag = str()

                # 답변의 총 갯수 파악
                answers_bundle = browser.find_elements_by_css_selector('.box_type1.hidoc_answer')
                len(answers_bundle)

                answer_list= []
                for answer in answers_bundle: 
                    try : 
                        answer_title = browser.find_element_by_css_selector('div.view_answer > div:nth-child(28) > strong').text
                    except :
                        answer_title = str()
                    try : 
                        answer_name = browser.find_element_by_css_selector('div:nth-child(29) > div.answer_head > div.doctor_clinic > a').text
                    except: 
                        answer_name = str()
                    try : 
                        answer_belong = browser.find_element_by_css_selector('div:nth-child(29) > div.answer_head > div.doctor_clinic > span').text
                    except:
                        answer_belong=str()
                    try : 
                        answer_content = browser.find_element_by_css_selector('div.view_answer > div:nth-child(29) > div.answer_body > div > div:nth-child(1)').text
                    except:
                        answer_content = str()

                    answers_list = [question_title, question_content, question_date, question_tag, answer_title, answer_name, answer_belong, answer_content ]
                    answer_list.append(answers_list)
                browser.back() #팝업 닫기
                
            pagination = browser.find_element_by_css_selector(page_path)
            pagination.click()
            
            # 현재 페이지의 데이터를 comm_list에 추가
            comm_list.extend(answer_list)
            # answer_list 초기화
            answer_list = []
            
        except : 
            print("오류")
            
    next_page = browser.find_element_by_css_selector('span > a.ico_comm.btn_next').click()
        
    # 저장을 위한 작업
    comm_colums_name = ['question_title', 'question_content', 'question_date', 'question_tag', 'answer_title', 'answer_name', 'answer_belong', 'answer_content' ]
    df_comm = pd.DataFrame(data=comm_list, columns=comm_colums_name)
    data_dict = df_comm.to_dict(orient='records')
    collection.insert_many(data_dict)
# Out:
# 성공 : 2
# 성공 : 3
# 성공 : 4
# 성공 : 5
# 오류
# 성공 : 6
# 오류
# 성공 : 7
# 오류
# 성공 : 8
# 오류
# 성공 : 9
# 오류
# 성공 : 10
# 오류
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[142], line 79
#      76     except :
#      77         print("오류")
# ---> 79 next_page = browser.find_element_by_css_selector('span > a.ico_comm.btn_next').click()
#      81 # 저장을 위한 작업
#      82 comm_colums_name = ['question_title', 'question_content', 'question_date', 'question_tag', 'answer_title', 'answer_name', 'answer_belong', 'answer_content' ]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:598, in WebDriver.find_element_by_css_selector(self, css_selector)
#     582 def find_element_by_css_selector(self, css_selector):
#     583     """
#     584     Finds an element by css selector.
#     585
#    (...)
#     596         element = driver.find_element_by_css_selector('#foo')
#     597     """
# --> 598     return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=116.0.5845.180)
